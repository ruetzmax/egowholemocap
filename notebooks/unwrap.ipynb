# %%
# source:
# https://medium.com/check-visit-computer-vision/understanding-360-images-8e0fcf0ee861

# %%
import numpy as np
from typing import List
import cv2
import numpy as np

# %%
def sample_pixels(begin: float, end: float, n: int) -> np.ndarray:
    """
    Sample pixel values of an affine function, which is equal
    to "begin" on the far left and "end" on the far right.
    """
    x_coords = 0.5 + np.arange(n, dtype=np.float32)
    return begin + (end-begin) * x_coords / n  # ]begin, end[

# %%
def equirec_to_cubemap(equirec: np.ndarray, out_size: int) -> List[np.ndarray]:
    """Convert an equirectangular image to a list of cubefaces (FRBLUD)"""
    height, width = equirec.shape[:2]

    u, v = np.meshgrid(sample_pixels(-1, 1, out_size),
                       sample_pixels(-1, 1, out_size),
                       indexing="ij")
    ones = np.ones((out_size, out_size), dtype=np.float32)

    list_xyz = [
        (v, u, ones),    # FRONT
        (ones, u, -v),   # RIGHT
        (-v, u, -ones),  # BACK
        (-ones, u, v),   # LEFT
        (v, -ones, u),   # UP
        (v, ones, -u)    # DOWN
    ]

    faces = []
    r = np.sqrt(u**2 + v**2 + 1) # Same values for each face
    for x, y, z in list_xyz:
        # Camera Convention RIGHT_DOWN_FRONT
        phi = np.arcsin(y/r)  # in [-pi/2, pi/2]
        theta = np.arctan2(x, z)  # in [-pi, pi]

        phi_map = (phi/np.pi + 0.5) * height
        theta_map = (theta/(2*np.pi) + 0.5) * width
    
        # Opencv shift
        theta_map -= 0.5
        phi_map -= 0.5
        
        faces.append(cv2.remap(equirec, theta_map, phi_map, cv2.INTER_CUBIC,
                               borderMode=cv2.BORDER_WRAP))
    return faces

# %%
# unwrap and export front face for every frame
cap = cv2.VideoCapture("vids/pickup.mp4")

if not cap.isOpened():
    raise IOError("Cannot open video")

frame_idx = 0
ret = True
while ret:
    ret, frame = cap.read()

    faces = equirec_to_cubemap(frame, 512)

    front_face = faces[0]
    front_face = cv2.rotate(front_face, cv2.ROTATE_90_COUNTERCLOCKWISE)
    cv2.imwrite(f"unwrapped/{frame_idx}.jpg", front_face)
    frame_idx+=1
    print(f"Exported face {frame_idx}")
# Out:
# Exported face 1
# Exported face 2
# Exported face 3
# Exported face 4
# Exported face 5
# Exported face 6
# Exported face 7
# Exported face 8
# Exported face 9
# Exported face 10
# Exported face 11
# Exported face 12
# Exported face 13
# Exported face 14
# Exported face 15
# Exported face 16
# Exported face 17
# Exported face 18
# Exported face 19
# Exported face 20
# Exported face 21
# Exported face 22
# Exported face 23
# Exported face 24
# Exported face 25
# Exported face 26
# Exported face 27
# Exported face 28
# Exported face 29
# Exported face 30
# Exported face 31
# Exported face 32
# Exported face 33
# Exported face 34
# Exported face 35
# Exported face 36
# Exported face 37
# Exported face 38
# Exported face 39
# Exported face 40
# Exported face 41
# Exported face 42
# Exported face 43
# Exported face 44
# Exported face 45
# Exported face 46
# Exported face 47
# Exported face 48
# Exported face 49
# Exported face 50
# Exported face 51
# Exported face 52
# Exported face 53
# Exported face 54
# Exported face 55
# Exported face 56
# Exported face 57
# Exported face 58
# Exported face 59
# Exported face 60
# Exported face 61
# Exported face 62
# Exported face 63
# Exported face 64
# Exported face 65
# Exported face 66
# Exported face 67
# Exported face 68
# Exported face 69
# Exported face 70
# Exported face 71
# Exported face 72
# Exported face 73
# Exported face 74
# Exported face 75
# Exported face 76
# Exported face 77
# Exported face 78
# Exported face 79
# Exported face 80
# Exported face 81
# Exported face 82
# Exported face 83
# Exported face 84
# Exported face 85
# Exported face 86
# Exported face 87
# Exported face 88
# Exported face 89
# Exported face 90
# Exported face 91
# Exported face 92
# Exported face 93
# Exported face 94
# Exported face 95
# Exported face 96
# Exported face 97
# Exported face 98
# Exported face 99
# Exported face 100
# Exported face 101
# Exported face 102
# Exported face 103
# Exported face 104
# Exported face 105
# Exported face 106
# Exported face 107
# Exported face 108
# Exported face 109
# Exported face 110
# Exported face 111
# Exported face 112
# Exported face 113
# Exported face 114
# Exported face 115
# Exported face 116
# Exported face 117
# Exported face 118
# Exported face 119
# Exported face 120
# Exported face 121
# Exported face 122
# Exported face 123
# Exported face 124
# Exported face 125
# Exported face 126
# Exported face 127
# Exported face 128
# Exported face 129
# Exported face 130
# Exported face 131
# Exported face 132
# Exported face 133
# Exported face 134
# Exported face 135
# Exported face 136
# Exported face 137
# Exported face 138
# Exported face 139
# Exported face 140
# Exported face 141
# Exported face 142
# Exported face 143
# Exported face 144
# Exported face 145
# Exported face 146
# Exported face 147
# Exported face 148
# Exported face 149
# Exported face 150
# Exported face 151
# Exported face 152
# Exported face 153
# Exported face 154
# Exported face 155
# Exported face 156
# Exported face 157
# Exported face 158
# Exported face 159
# Exported face 160
# Exported face 161
# Exported face 162
# Exported face 163
# Exported face 164
# Exported face 165
# Exported face 166
# Exported face 167
# Exported face 168
# Exported face 169
# Exported face 170
# Exported face 171
# Exported face 172
# Exported face 173
# Exported face 174
# Exported face 175
# Exported face 176
# Exported face 177
# Exported face 178
# Exported face 179
# Exported face 180
# Exported face 181
# Exported face 182
# Exported face 183
# Exported face 184
# Exported face 185
# Exported face 186
# Exported face 187
# Exported face 188
# Exported face 189
# Exported face 190
# Exported face 191
# Exported face 192
# Exported face 193
# Exported face 194
# Exported face 195
# Exported face 196
# Exported face 197
# Exported face 198
# Exported face 199
# Exported face 200
# Exported face 201
# Exported face 202
# Exported face 203
# Exported face 204
# Exported face 205
# Exported face 206
# Exported face 207
# Exported face 208
# Exported face 209
# Exported face 210
# Exported face 211
# Exported face 212
# Exported face 213
# Exported face 214
# Exported face 215
# Exported face 216
# Exported face 217
# Exported face 218
# Exported face 219
# Exported face 220
# Exported face 221
# Exported face 222
# Exported face 223
# Exported face 224
# Exported face 225
# Exported face 226
# Exported face 227
# Exported face 228
# Exported face 229
# Exported face 230
# Exported face 231
# Exported face 232
# Exported face 233
# Exported face 234
# Exported face 235
# Exported face 236
# Exported face 237
# Exported face 238
# Exported face 239
# Exported face 240
# Exported face 241
# Exported face 242
# Exported face 243
# Exported face 244
# Exported face 245
# Exported face 246
# Exported face 247
# Exported face 248
# Exported face 249
# Exported face 250
# Exported face 251
# Exported face 252
# Exported face 253
# Exported face 254
# Exported face 255
# Exported face 448
# Exported face 449
# Exported face 450
# Exported face 451
# Exported face 452
# Exported face 453
# Exported face 454
# Exported face 455
# Exported face 456
# Exported face 457
# Exported face 458
# Exported face 459
# Exported face 460
# Exported face 461
# Exported face 462
# Exported face 463
# Exported face 464
# Exported face 465
# Exported face 466
# Exported face 467
# Exported face 468
# Exported face 469
# Exported face 470
# Exported face 471
# Exported face 472
# Exported face 473
# Exported face 474
# Exported face 475
# Exported face 476
# Exported face 477
# Exported face 478
# Exported face 479
# Exported face 480
# Exported face 481
# Exported face 482
# Exported face 483
# Exported face 484
# Exported face 485
# Exported face 486
# Exported face 487
# Exported face 488
# Exported face 489
# Exported face 490
# Exported face 491
# Exported face 492
# Exported face 493
# Exported face 494
# Exported face 495
# Exported face 496
# Exported face 497
# Exported face 498
# Exported face 499
# Exported face 500
# Exported face 501
# Exported face 502
# Exported face 503
# Exported face 504
# Exported face 505
# Exported face 506
# Exported face 507
# Exported face 508
# Exported face 509
# Exported face 510
# Exported face 511
# Exported face 512
# Exported face 513
# Exported face 514
# Exported face 515
# Exported face 516
# Exported face 517
# Exported face 518
# Exported face 519
# Exported face 520
# Exported face 521
# Exported face 522
# Exported face 523
# Exported face 524
# Exported face 525
# Exported face 526
# Exported face 527
# Exported face 528
# Exported face 529
# Exported face 530
# Exported face 531
# Exported face 532
# Exported face 533
# Exported face 534
# Exported face 535
# Exported face 536
# Exported face 537
# Exported face 538
# Exported face 539
# Exported face 540
# Exported face 541
# Exported face 542
# Exported face 543
# Exported face 544
# Exported face 545
# Exported face 546
# Exported face 547
# Exported face 548
# Exported face 549
# Exported face 550
# Exported face 551
# Exported face 552
# Exported face 553
# Exported face 554
# Exported face 555
# Exported face 556
# Exported face 557
# Exported face 558
# Exported face 559
# Exported face 560
# Exported face 561
# Exported face 562
# Exported face 563
# Exported face 564
# Exported face 565
# Exported face 566
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 12
#       9 while ret:
#      10     ret, frame = cap.read()
# ---> 12     faces = equirec_to_cubemap(frame, 512)
#      14     front_face = faces[0]
#      15     front_face = cv2.rotate(front_face, cv2.ROTATE_90_COUNTERCLOCKWISE)
#
# Cell In[4], line 3, in equirec_to_cubemap(equirec, out_size)
#       1 def equirec_to_cubemap(equirec: np.ndarray, out_size: int) -> List[np.ndarray]:
#       2     """Convert an equirectangular image to a list of cubefaces (FRBLUD)"""
# ----> 3     height, width = equirec.shape[:2]
#       5     u, v = np.meshgrid(sample_pixels(-1, 1, out_size),
#       6                        sample_pixels(-1, 1, out_size),
#       7                        indexing="ij")
#       8     ones = np.ones((out_size, out_size), dtype=np.float32)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
#read single frame of vid
cap = cv2.VideoCapture("vids/pickup.mp4")

if not cap.isOpened():
    raise IOError("Cannot open video")

for i in range(210):
    ret, frame = cap.read()

if not ret:
    raise IOError("Cannot read first frame")


faces = equirec_to_cubemap(frame, 512)

for i, face in enumerate(faces):
    face = cv2.rotate(face, cv2.ROTATE_90_COUNTERCLOCKWISE)
    cv2.imwrite(f"unwrapped/face_{i}.jpg", face)

print("Exported cubemap")
# Out:
# Exported cubemap
